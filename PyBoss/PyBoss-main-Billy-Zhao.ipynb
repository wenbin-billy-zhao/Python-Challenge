# %% [markdown]
# Emp ID,Name,DOB,SSN,State
# 214,Sarah Simpson,1985-12-04,282-01-8166,Florida
# 15,Samantha Lara,1993-09-08,848-80-7526,Colorado
# 411,Stacy Charles,1957-12-20,658-75-8526,Pennsylvania

# %%
import os
import csv
from datetime import datetime

# %%
us_state_abbrev = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY',
}

# %%
def changeDOB(DOB):
    DOB = datetime.strptime(DOB, '%Y-%m-%d')
    DOB = DOB.strftime('%m/%d/%Y')
    return DOB

# %%
def maskSSN(SSN):
    SSN = "***-**-" + SSN[-4:]
    return SSN

# %%
def abbreState(State):
    for stateName, abbre in us_state_abbrev.items():
        if State == stateName:
            State = abbre
        else:
            State = 'NA'
        return State

# %%
file_name = 'employee_data.csv'
output_file_name = "employee_data_modified.csv"

with open(file_name, 'r') as csvfile, open(output_file_name, 'w') as outfile:
    csvreader = csv.reader(csvfile, delimiter = ',')
    csvwriter = csv.writer(outfile, delimiter = ',', lineterminator='\n')
    
    # skip the first row
    csvheader = next(csvreader)
    
    data = list(csvreader)

    for row in data:
        Name = row[1]
        firstName = Name.strip().split(' ')[0]
        lastName = Name.strip().split(' ')[1]
        row.append(firstName)
        row.append(lastName)
        
        # notice two different functions from datetime library
        # strptime() and strftime()
        DOB = changeDOB(row[2])
        row.append(DOB)
        
        SSN = maskSSN(row[3])
        row.append(SSN)
        
        State = abbreState(row[4])
        row.append(State)
        
        # remove rows that are no longer needed
        for i in range(4):
            del row[1]

    csvwriter.writerow(['Emp ID','First Name', 'Last Name','DoB', 'SSN', 'ST'])
    for row in data:
        csvwriter.writerow(row)

# %%
data
# Out:
# [['232', 'John', 'Mathews', '02/24/1991', '***-**-9165', 'NA'],
#  ['533', 'Nathan', 'Moore', '11/19/1978', '***-**-7469', 'NA'],
#  ['256', 'Amanda', 'Douglas', '01/08/1990', '***-**-6961', 'NA'],
#  ['189', 'Heather', 'Andrews', '08/11/1976', '***-**-1797', 'NA'],
#  ['284', 'Daniel', 'Hernandez', '07/22/1976', '***-**-7473', 'NA'],
#  ['512', 'Danny', 'Pena', '01/31/1978', '***-**-9878', 'NA'],
#  ['126', 'Gary', 'Knight', '03/08/1994', '***-**-1242', 'NA'],
#  ['556', 'Robin', 'Carroll', '10/14/1972', '***-**-7194', 'NA'],
#  ['595', 'Michelle', 'Dickerson', '02/08/1984', '***-**-2817', 'NA'],
#  ['191', 'Kimberly', 'Gallegos', '08/05/1972', '***-**-7563', 'NA'],
#  ['55', 'Morgan', 'Parker', '01/30/1986', '***-**-4320', 'NA'],
#  ['623', 'Mason', 'Rhodes', '01/28/1977', '***-**-4767', 'NA'],
#  ['426', 'Amy', 'Griffin', '02/18/1973', '***-**-1946', 'NA'],
#  ['535', 'Danielle', 'House', '04/16/1975', '***-**-9308', 'NA'],
#  ['399', 'Charles', 'Greene', '11/28/1992', '***-**-2935', 'NA'],
#  ['33', 'Nicholas', 'Martinez', '04/05/1979', '***-**-1689', 'NA'],
#  ['302', 'Tracey', 'Meadows', '01/12/1988', '***-**-6175', 'NA'],
#  ['325', 'Renee', 'Evans', '03/14/1991', '***-**-2708', 'NA'],
#  ['188', 'Joseph', 'Estrada', '03/29/1984', '***-**-2571', 'NA'],
#  ['184', 'Jeremy', 'Warner', '10/20/1987', '***-**-1184', 'AL'],
#  ['526', 'Anthony', 'Rodriguez', '02/09/1983', '***-**-3865', 'NA'],
#  ['85', 'Kristen', 'Lopez', '01/02/1978', '***-**-8194', 'NA'],
#  ['171', 'Mark', 'Mcdonald', '06/27/1984', '***-**-0101', 'NA'],
#  ['74', 'Robert', 'Freeman', '01/01/1984', '***-**-5211', 'NA'],
#  ['69', 'Michael', 'Reynolds', '10/30/1994', '***-**-8507', 'NA'],
#  ['365', 'Kristine', 'Little', '07/10/1974', '***-**-1771', 'NA'],
#  ['149', 'April', 'Barnes', '02/15/1983', '***-**-3288', 'NA'],
#  ['218', 'Pamela', 'Hodges', '02/19/1989', '***-**-1423', 'NA'],
#  ['647', 'Ronald', 'Gilbert', '05/26/1974', '***-**-4448', 'NA'],
#  ['518', 'Thomas', 'Cooper', '08/17/1972', '***-**-9890', 'NA'],
#  ['12', 'Dakota', 'Harrington', '08/24/1972', '***-**-7188', 'NA'],
#  ['622', 'Jennifer', 'Porter', '01/20/1991', '***-**-5572', 'NA'],
#  ['159', 'Beverly', 'Jordan', '08/15/1986', '***-**-3762', 'NA'],
#  ['394', 'Mark', 'Brown', '04/02/1975', '***-**-8531', 'NA'],
#  ['158', 'Amy', 'Ford', '06/05/1974', '***-**-6461', 'NA'],
#  ['446', 'Benjamin', 'King', '05/07/1973', '***-**-8165', 'NA'],
#  ['352', 'Stephen', 'Bryant', '05/15/1991', '***-**-6488', 'NA'],
#  ['598', 'Brandi', 'Williams', '10/15/1989', '***-**-8500', 'NA'],
#  ['505', 'Ashley', 'Hutchinson', '04/26/1994', '***-**-1510', 'NA'],
#  ['173', 'Alisha', 'Pacheco', '01/13/1982', '***-**-2496', 'NA'],
#  ['84', 'Robert', 'Campbell', '02/27/1973', '***-**-9581', 'NA'],
#  ['406', 'Sandra', 'Sanders', '10/06/1980', '***-**-1673', 'NA'],
#  ['164', 'Katherine', 'Hensley', '05/29/1991', '***-**-7226', 'NA'],
#  ['267', 'Stacy', 'Cox', '11/08/1976', '***-**-0990', 'AL'],
#  ['503', 'Frank', 'Barton', '06/10/1993', '***-**-5568', 'NA'],
#  ['295', 'Shannon', 'Kramer', '05/04/1980', '***-**-7615', 'NA'],
#  ['590', 'Brenda', 'James', '12/31/1977', '***-**-3251', 'NA'],
#  ['97', 'Paula', 'Edwards', '08/10/1988', '***-**-0638', 'NA'],
#  ['3', 'Jennifer', 'Rowe', '09/16/1980', '***-**-9014', 'NA'],
#  ['20', 'David', 'Foster', '01/09/1990', '***-**-6956', 'NA'],
#  ['179', 'William', 'Boyle', '01/30/1988', '***-**-0490', 'NA'],
#  ['86', 'Christopher', 'Greene', '05/29/1972', '***-**-8446', 'NA'],
#  ['219', 'Matthew', 'Fuller', '04/27/1980', '***-**-2989', 'NA'],
#  ['237', 'Gabriela', 'Nguyen', '12/17/1981', '***-**-3729', 'NA'],
#  ['96', 'Allison', 'Diaz', '03/25/1994', '***-**-8927', 'NA'],
#  ['22', 'Isaac', 'Jordan', '05/06/1986', '***-**-0520', 'NA'],
#  ['439', 'Cheryl', 'Bailey', '10/31/1991', '***-**-1224', 'NA'],
#  ['146', 'Julie', 'Castillo', '02/16/1988', '***-**-4523', 'NA'],
#  ['271', 'Michael', 'Adams', '12/10/1986', '***-**-3927', 'NA'],
#  ['103', 'Melinda', 'Parsons', '02/07/1986', '***-**-8751', 'NA'],
#  ['540', 'Robert', 'Campbell', '01/17/1987', '***-**-3694', 'NA'],
#  ['144', 'Julie', 'Nelson', '08/08/1994', '***-**-1332', 'NA'],
#  ['594', 'Steven', 'Nelson', '04/14/1989', '***-**-2085', 'NA'],
#  ['176', 'Hailey', 'Lynn', '03/25/1973', '***-**-9488', 'NA'],
#  ['198', 'Dillon', 'Nguyen', '05/26/1978', '***-**-4552', 'NA'],
#  ['433', 'Hannah', 'Miller', '10/18/1973', '***-**-4657', 'NA'],
#  ['274', 'Jeffrey', 'Harris', '05/25/1994', '***-**-4763', 'NA'],
#  ['6', 'Daniel', 'Welch', '08/08/1982', '***-**-6950', 'NA'],
#  ['452', 'Bryan', 'Jackson', '09/08/1982', '***-**-8117', 'NA'],
#  ['23', 'Denise', 'George', '09/07/1990', '***-**-4879', 'NA'],
#  ['373', 'Alicia', 'Carney', '09/10/1989', '***-**-9437', 'NA'],
#  ['374', 'William', 'Peters', '03/20/1986', '***-**-7516', 'NA'],
#  ['200', 'Dustin', 'Drake', '09/17/1993', '***-**-5454', 'NA'],
#  ['428', 'Jessica', 'Thornton', '01/03/1983', '***-**-2381', 'NA'],
#  ['116', 'Rebecca', 'Wilson', '06/08/1980', '***-**-6629', 'NA'],
#  ['418', 'Katherine', 'Lane', '11/01/1986', '***-**-6820', 'NA'],
#  ['9', 'Sarah', 'Harper', '07/27/1993', '***-**-5891', 'NA'],
#  ['230', 'Jermaine', 'Hill', '09/11/1988', '***-**-5479', 'NA'],
#  ['502', 'Michael', 'Marshall', '04/05/1990', '***-**-5125', 'NA'],
#  ['632', 'Kirsten', 'Mcbride', '09/10/1973', '***-**-2372', 'NA'],
#  ['112', 'Rachael', 'Holmes', '07/30/1973', '***-**-2067', 'NA'],
#  ['422', 'Leon', 'Foster', '09/19/1975', '***-**-3153', 'NA'],
#  ['131', 'David', 'Mcclain', '08/02/1976', '***-**-5430', 'NA'],
#  ['404', 'Emily', 'Lawrence', '11/24/1991', '***-**-1991', 'NA'],
#  ['504', 'Troy', 'Booth', '12/27/1990', '***-**-5141', 'NA'],
#  ['194', 'Stephanie', 'Ho', '04/25/1983', '***-**-3656', 'NA'],
#  ['567', 'Michele', 'Hendricks', '03/10/1990', '***-**-7341', 'NA'],
#  ['253', 'Eric', 'Harper', '11/12/1986', '***-**-2860', 'NA'],
#  ['407', 'Jonathan', 'Gomez', '06/05/1993', '***-**-4727', 'NA'],
#  ['82', 'Kevin', 'Garcia', '11/25/1977', '***-**-4722', 'NA'],
#  ['429', 'Howard', 'Lawson', '04/13/1984', '***-**-7664', 'NA'],
#  ['78', 'Stacy', 'Robertson', '09/24/1974', '***-**-0248', 'NA'],
#  ['167', 'John', 'Beck', '07/27/1985', '***-**-3635', 'NA'],
#  ['484', 'Julia', 'Morgan', '03/18/1976', '***-**-1731', 'NA'],
#  ['60', 'Allen', 'Leon', '04/06/1975', '***-**-9089', 'NA'],
#  ['400', 'James', 'Rios', '03/04/1978', '***-**-3987', 'NA'],
#  ['34', 'Ralph', 'Wells', '10/19/1988', '***-**-4237', 'NA'],
#  ['596', 'Megan', 'Chavez', '10/08/1991', '***-**-7659', 'NA'],
#  ['279', 'Ashley', 'Patrick', '06/07/1974', '***-**-0763', 'NA'],
#  ['466', 'Bonnie', 'Bowen', '11/07/1993', '***-**-5889', 'NA'],
#  ['327', 'Andrew', 'Lawson', '04/05/1982', '***-**-7313', 'NA'],
#  ['382', 'Tonya', 'Chavez', '04/17/1984', '***-**-5703', 'NA'],
#  ['369', 'Michelle', 'Larson', '03/20/1980', '***-**-3866', 'NA'],
#  ['347', 'Mark', 'Garrett', '09/18/1985', '***-**-4408', 'NA'],
#  ['25', 'Chelsea', 'Rivera', '06/21/1987', '***-**-0140', 'NA'],
#  ['317', 'Amanda', 'Krause', '11/06/1977', '***-**-4744', 'NA'],
#  ['321', 'Paige', 'Spencer', '09/02/1991', '***-**-8621', 'NA'],
#  ['193', 'Rhonda', 'Gonzales', '06/07/1976', '***-**-4110', 'NA'],
#  ['606', 'Jasmine', 'Kelly', '06/30/1979', '***-**-3251', 'NA'],
#  ['123', 'Amy', 'Sherman', '08/04/1973', '***-**-6029', 'NA'],
#  ['566', 'David', 'Arroyo', '04/16/1975', '***-**-9403', 'NA'],
#  ['409', 'Robert', 'Lin', '11/12/1975', '***-**-0121', 'NA'],
#  ['265', 'Paul', 'Wilson', '06/19/1993', '***-**-9871', 'NA'],
#  ['490', 'Paul', 'Meyers', '03/13/1989', '***-**-1680', 'NA'],
#  ['311', 'Jessica', 'Elliott', '06/04/1978', '***-**-1632', 'NA'],
#  ['537', 'Anthony', 'Richmond', '10/05/1989', '***-**-8935', 'NA'],
#  ['147', 'William', 'Rivera', '03/08/1975', '***-**-7032', 'NA'],
#  ['304', 'Sheri', 'Villegas', '02/13/1985', '***-**-8629', 'NA'],
#  ['472', 'Kelly', 'Hopkins', '10/08/1984', '***-**-6875', 'NA'],
#  ['348', 'Darren', 'Farrell', '05/24/1991', '***-**-5885', 'NA'],
#  ['91', 'Darlene', 'Harmon', '05/05/1980', '***-**-3052', 'NA'],
#  ['410', 'Rachel', 'Lyons', '08/29/1972', '***-**-0900', 'NA'],
#  ['344', 'David', 'Jacobs', '02/28/1982', '***-**-3682', 'NA'],
#  ['419', 'Christina', 'Weeks', '10/15/1972', '***-**-2028', 'NA'],
#  ['1', 'Andrea', 'Anderson', '11/12/1984', '***-**-5650', 'NA'],
#  ['532', 'Jennifer', 'Smith', '01/31/1989', '***-**-1748', 'NA'],
#  ['107', 'Shirley', 'Andrews', '12/07/1981', '***-**-5306', 'NA'],
#  ['166', 'Adrian', 'Rivera', '02/13/1973', '***-**-5638', 'NA'],
#  ['391', 'George', 'Mckinney', '02/04/1984', '***-**-7748', 'NA'],
#  ['67', 'Hailey', 'Boyd', '11/17/1980', '***-**-0270', 'NA'],
#  ['447', 'Tiffany', 'Harris', '01/12/1983', '***-**-9733', 'NA'],
#  ['653', 'Mary', 'Hunter', '11/01/1977', '***-**-6623', 'NA'],
#  ['294', 'Robert', 'Edwards', '04/07/1980', '***-**-5215', 'NA'],
#  ['416', 'Barbara', 'Lambert', '09/07/1979', '***-**-5353', 'NA'],
#  ['185', 'Angela', 'Armstrong', '03/22/1990', '***-**-2446', 'NA'],
#  ['637', 'Brett', 'Ward', '09/27/1979', '***-**-0204', 'NA'],
#  ['333', 'Troy', 'Sanchez', '11/15/1990', '***-**-2052', 'NA'],
#  ['579', 'Garrett', 'Carter', '09/26/1988', '***-**-7246', 'NA'],
#  ['215', 'James', 'Reeves', '01/31/1988', '***-**-1620', 'NA'],
#  ['152', 'Mary', 'Baker', '07/08/1979', '***-**-0954', 'NA'],
#  ['301', 'Alexandra', 'Bradley', '06/13/1980', '***-**-9390', 'AL'],
#  ['572', 'Aaron', 'James', '03/25/1974', '***-**-4596', 'NA'],
#  ['165', 'Thomas', 'Wood', '08/21/1979', '***-**-8269', 'NA'],
#  ['639', 'Charlene', 'Jackson', '10/28/1989', '***-**-8809', 'NA'],
#  ['405', 'Mary', 'Robbins', '12/01/1975', '***-**-9514', 'NA'],
#  ['390', 'Kayla', 'Washington', '10/08/1985', '***-**-6218', 'NA'],
#  ['641', 'Kimberly', 'Knapp', '11/23/1992', '***-**-1122', 'NA'],
#  ['51', 'Nicholas', 'Brown', '09/18/1988', '***-**-2869', 'NA'],
#  ['421', 'Rebecca', 'Marshall', '05/06/1974', '***-**-1020', 'NA'],
#  ['106', 'Mark', 'Smith', '07/07/1979', '***-**-5381', 'NA'],
#  ['379', 'Adam', 'Harrell', '10/18/1981', '***-**-0742', 'NA'],
#  ['76', 'Steve', 'Daniels', '09/14/1980', '***-**-3537', 'NA'],
#  ['68', 'Victoria', 'Potter', '03/25/1988', '***-**-4290', 'NA'],
#  ['118', 'Kathy', 'Preston', '03/06/1990', '***-**-9960', 'NA'],
#  ['127', 'Michael', 'Donaldson', '01/01/1995', '***-**-7624', 'NA'],
#  ['542', 'Brian', 'Bridges', '02/22/1976', '***-**-4546', 'NA'],
#  ['181', 'Martha', 'Gonzalez', '01/17/1981', '***-**-8342', 'NA'],
#  ['111', 'Paul', 'Rogers', '01/10/1992', '***-**-6284', 'NA'],
#  ['481', 'Dawn', 'Galvan', '09/03/1989', '***-**-8058', 'NA'],
#  ['568', 'Amber', 'West', '01/19/1978', '***-**-7363', 'NA'],
#  ['395', 'Christopher', 'Guerrero', '01/29/1983', '***-**-4036', 'NA'],
#  ['345', 'Stacy', 'Brooks', '06/17/1991', '***-**-4661', 'NA'],
#  ['438', 'Danielle', 'Kaiser', '08/21/1975', '***-**-9764', 'AL'],
#  ['403', 'Taylor', 'Boyle', '09/26/1979', '***-**-9756', 'NA'],
#  ['180', 'Donna', 'Howard', '12/16/1978', '***-**-3416', 'NA'],
#  ['616', 'Anne', 'Rios', '11/26/1974', '***-**-6513', 'NA'],
#  ['56', 'Theresa', 'Barnes', '09/28/1976', '***-**-2054', 'NA'],
#  ['153', 'Lori', 'Tate', '03/08/1977', '***-**-9123', 'NA'],
#  ['551', 'Alexandria', 'Baker', '11/02/1974', '***-**-3200', 'NA'],
#  ['135', 'Stephen', 'Hensley', '09/30/1978', '***-**-5372', 'NA'],
#  ['500', 'Jennifer', 'Fischer', '11/19/1983', '***-**-5609', 'NA'],
#  ['24', 'Pamela', 'Robinson', '02/21/1981', '***-**-4275', 'NA'],
#  ['81', 'Brendan', 'Gonzalez', '08/02/1991', '***-**-9993', 'NA'],
#  ['50', 'Richard', 'Turner', '12/24/1982', '***-**-9924', 'NA'],
#  ['328', 'Michael', 'Robinson', '10/22/1973', '***-**-2355', 'NA'],
#  ['402', 'Patricia', 'Sharp', '07/13/1987', '***-**-0306', 'NA'],
#  ['255', 'Elizabeth', 'Avila', '03/15/1977', '***-**-8453', 'NA'],
#  ['413', 'Christopher', 'Martinez', '12/28/1978', '***-**-8774', 'NA'],
#  ['507', 'Isaac', 'Woods', '03/20/1984', '***-**-6227', 'NA'],
#  ['62', 'Adriana', 'Wolf', '10/17/1994', '***-**-1702', 'NA'],
#  ['150', 'David', 'Pearson', '06/14/1982', '***-**-1781', 'AL'],
#  ['109', 'Matthew', 'Kramer', '05/14/1988', '***-**-4860', 'NA'],
#  ['310', 'Pamela', 'Archer', '10/25/1987', '***-**-2625', 'NA'],
#  ['243', 'Charles', 'Stout', '12/05/1976', '***-**-1997', 'NA'],
#  ['72', 'Daniel', 'Boyd', '07/18/1978', '***-**-1220', 'NA'],
#  ['608', 'Jimmy', 'Jones', '02/19/1973', '***-**-2030', 'NA'],
#  ['19', 'Rebecca', 'Hammond', '02/21/1972', '***-**-2706', 'NA'],
#  ['30', 'Emily', 'Diaz', '12/04/1986', '***-**-9174', 'NA'],
#  ['119', 'Chad', 'Wise', '11/10/1988', '***-**-1355', 'NA'],
#  ['162', 'Todd', 'Duran', '01/14/1976', '***-**-1832', 'NA'],
#  ['199', 'Brian', 'Mclaughlin', '09/21/1987', '***-**-2876', 'NA'],
#  ['187', 'Katherine', 'Rogers', '05/13/1988', '***-**-9500', 'NA'],
#  ['102', 'Joseph', 'Adams', '01/18/1979', '***-**-7778', 'NA'],
#  ['385', 'David', 'Lowery', '10/21/1987', '***-**-7963', 'NA'],
#  ['626', 'Janice', 'Young', '07/07/1988', '***-**-4863', 'NA'],
#  ['528', 'Anna', 'Matthews', '02/09/1991', '***-**-4474', 'NA'],
#  ['31', 'Katie', 'Garcia', '03/22/1983', '***-**-8462', 'NA'],
#  ['43', 'Maria', 'Estrada', '04/30/1990', '***-**-8108', 'NA'],
#  ['169', 'Ashley', 'Smith', '07/16/1983', '***-**-8720', 'NA'],
#  ['204', 'Amy', 'Wright', '10/15/1991', '***-**-8641', 'NA'],
#  ['494', 'Heather', 'Scott', '08/20/1982', '***-**-0361', 'NA'],
#  ['233', 'John', 'Anderson', '05/30/1973', '***-**-6681', 'NA'],
#  ['638', 'John', 'Anderson', '01/07/1983', '***-**-7935', 'NA'],
#  ['57', 'Kimberly', 'Harris', '10/01/1988', '***-**-5459', 'NA'],
#  ['648', 'Christopher', 'Smith', '11/23/1976', '***-**-2521', 'NA'],
#  ['192', 'Daniel', 'Singh', '12/25/1980', '***-**-7521', 'NA'],
#  ['73', 'Miranda', 'Nguyen', '08/12/1981', '***-**-2585', 'NA'],
#  ['477', 'Gregory', 'Simpson', '07/09/1990', '***-**-9365', 'NA'],
#  ['411', 'Daniel', 'Brown', '04/19/1984', '***-**-6526', 'NA'],
#  ['630', 'Susan', 'Thompson', '05/17/1985', '***-**-6074', 'NA'],
#  ['600', 'Rick', 'Johns', '07/30/1984', '***-**-7121', 'NA'],
#  ['634', 'Sean', 'Calhoun', '07/31/1978', '***-**-2261', 'NA'],
#  ['296', 'Alan', 'Holden', '11/06/1994', '***-**-6916', 'NA'],
#  ['154', 'Robin', 'Silva', '07/14/1987', '***-**-0453', 'NA'],
#  ['527', 'Nicole', 'Conrad', '06/02/1985', '***-**-6985', 'NA'],
#  ['635', 'Deanna', 'Russell', '07/29/1972', '***-**-9236', 'NA'],
#  ['229', 'Joshua', 'Bailey', '07/20/1986', '***-**-4031', 'NA'],
#  ['389', 'Daniel', 'Patrick', '10/15/1972', '***-**-8777', 'NA'],
#  ['220', 'William', 'Smith', '06/04/1990', '***-**-0654', 'NA'],
#  ['454', 'Kristin', 'Grant', '08/23/1980', '***-**-9693', 'NA'],
#  ['488', 'Kimberly', 'Velasquez', '01/10/1989', '***-**-4229', 'NA'],
#  ['41', 'Michael', 'Dalton', '03/08/1994', '***-**-2101', 'NA'],
#  ['522', 'Jason', 'Shaw', '11/01/1985', '***-**-4765', 'NA'],
#  ['269', 'Jonathon', 'Olson', '07/08/1985', '***-**-7767', 'NA'],
#  ['35', 'Andrea', 'Perry', '02/01/1986', '***-**-8897', 'NA'],
#  ['10', 'Anthony', 'Nguyen', '10/09/1986', '***-**-8472', 'NA'],
#  ['397', 'Anthony', 'Christensen', '05/13/1983', '***-**-8703', 'NA'],
#  ['45', 'Paul', 'Murphy', '07/18/1975', '***-**-9454', 'NA'],
#  ['210', 'Susan', 'Stewart', '04/23/1989', '***-**-2712', 'NA'],
#  ['197', 'Scott', 'Warren', '06/24/1985', '***-**-3723', 'NA'],
#  ['354', 'Jennifer', 'Avery', '08/08/1987', '***-**-5062', 'NA'],
#  ['552', 'Alexander', 'Vaughan', '08/22/1988', '***-**-8562', 'NA'],
#  ['414', 'Laura', 'Parker', '12/05/1973', '***-**-6879', 'NA'],
#  ['134', 'Derek', 'Harrington', '09/15/1990', '***-**-2836', 'NA'],
#  ['11', 'Daniel', 'Wells', '08/27/1994', '***-**-7268', 'NA'],
#  ['222', 'Kelly', 'Phillips', '11/05/1987', '***-**-1324', 'NA'],
#  ['442', 'Lauren', 'Bennett', '06/05/1985', '***-**-4874', 'NA'],
#  ['633', 'Aaron', 'Wolf', '04/09/1978', '***-**-1149', 'NA'],
#  ['361', 'Julia', 'Wright', '09/04/1980', '***-**-6702', 'NA'],
#  ['205', 'Cheryl', 'Dennis', '06/16/1986', '***-**-0712', 'NA'],
#  ['18', 'Donna', 'Lopez', '02/22/1985', '***-**-5711', 'NA'],
#  ['459', 'Matthew', 'Gibbs', '06/12/1984', '***-**-9698', 'NA'],
#  ['564', 'Nancy', 'Mitchell', '02/02/1988', '***-**-9365', 'NA'],
#  ['138', 'Ashley', 'Bullock', '07/23/1983', '***-**-5394', 'NA'],
#  ['356', 'Andrew', 'Moore', '01/03/1982', '***-**-5178', 'NA'],
#  ['479', 'Joseph', 'Martinez', '10/05/1973', '***-**-9409', 'NA'],
#  ['100', 'Yvette', 'Rodriguez', '09/11/1985', '***-**-8123', 'NA'],
#  ['451', 'Carrie', 'Barber', '11/09/1977', '***-**-3083', 'NA'],
#  ['432', 'Ashley', 'Sherman', '10/01/1984', '***-**-1501', 'NA'],
#  ['71', 'Craig', 'Garcia', '08/18/1994', '***-**-3695', 'NA'],
#  ['463', 'Jerome', 'Brown', '07/10/1992', '***-**-9456', 'NA'],
#  ['308', 'Kevin', 'Beck', '03/29/1981', '***-**-7304', 'NA'],
#  ['591', 'Travis', 'Hansen', '07/28/1981', '***-**-6746', 'NA'],
#  ['214', 'Rodney', 'Cook', '12/15/1994', '***-**-6232', 'NA'],
#  ['290', 'Theresa', 'Brown', '02/20/1993', '***-**-3478', 'NA'],
#  ['8', 'Wayne', 'Mercer', '09/21/1989', '***-**-7254', 'NA'],
#  ['182', 'Mary', 'Lee', '04/12/1982', '***-**-7361', 'NA'],
#  ['534', 'Matthew', 'Martin', '07/12/1993', '***-**-7803', 'NA'],
#  ['511', 'Lee', 'Weber', '12/03/1988', '***-**-9830', 'NA'],
#  ['32', 'James', 'Wilson', '07/23/1977', '***-**-7343', 'NA'],
#  ['289', 'Angela', 'Clark', '04/20/1988', '***-**-3392', 'NA'],
#  ['643', 'Allen', 'Flynn', '07/25/1994', '***-**-7573', 'NA'],
#  ['234', 'Darrell', 'Coleman', '08/24/1992', '***-**-4198', 'NA'],
#  ['618', 'Patrick', 'Wells', '08/03/1979', '***-**-3209', 'NA'],
#  ['246', 'Tyler', 'Beck', '10/20/1986', '***-**-1385', 'NA'],
#  ['546', 'Michelle', 'Jenkins', '11/29/1977', '***-**-8254', 'NA'],
#  ['455', 'Scott', 'Miller', '09/27/1991', '***-**-3580', 'NA'],
#  ['341', 'Maria', 'Mcmillan', '09/07/1973', '***-**-3730', 'NA'],
#  ['252', 'Amy', 'Waller', '10/01/1980', '***-**-8763', 'NA'],
#  ['351', 'Jacob', 'Thomas', '03/31/1976', '***-**-8896', 'NA'],
#  ['493', 'Amanda', 'Jones', '07/31/1993', '***-**-0691', 'NA'],
#  ['599', 'Edward', 'Padilla', '10/09/1993', '***-**-5222', 'NA'],
#  ['315', 'Debra', 'Best', '02/20/1973', '***-**-3320', 'NA'],
#  ['577', 'Gregory', 'Roberts', '01/27/1986', '***-**-4496', 'NA'],
#  ['415', 'Suzanne', 'Wheeler', '05/19/1985', '***-**-2982', 'NA'],
#  ['303', 'Ann', 'Lewis', '01/14/1976', '***-**-0619', 'NA'],
#  ['478', 'Michelle', 'Peterson', '06/25/1984', '***-**-2154', 'NA'],
#  ['313', 'Adam', 'Thomas', '12/30/1982', '***-**-1297', 'NA'],
#  ['4', 'Donna', 'Owens', '09/26/1987', '***-**-6696', 'AL'],
#  ['249', 'Pamela', 'Lyons', '09/27/1972', '***-**-3318', 'NA'],
#  ['649', 'Victor', 'Lopez', '10/26/1987', '***-**-3964', 'NA'],
#  ['565', 'Matthew', 'Miller', '04/07/1979', '***-**-3517', 'NA'],
#  ['513', 'Kevin', 'Foster', '10/18/1985', '***-**-5090', 'NA'],
#  ['516', 'Alyssa', 'Stokes', '04/01/1973', '***-**-2432', 'NA'],
#  ['545', 'Mark', 'Saunders', '08/23/1973', '***-**-2640', 'NA'],
#  ['38', 'Michael', 'Chapman', '03/13/1977', '***-**-6874', 'NA'],
#  ['309', 'Cole', 'Farrell', '01/29/1993', '***-**-7973', 'NA'],
#  ['578', 'Michael', 'Estrada', '10/12/1994', '***-**-2448', 'NA'],
#  ['178', 'Shaun', 'Martinez', '12/11/1982', '***-**-5793', 'NA'],
#  ['359', 'Victoria', 'Moon', '01/06/1976', '***-**-8604', 'NA'],
#  ['278', 'Brian', 'Peters', '05/07/1982', '***-**-3701', 'NA'],
#  ['292', 'Jose', 'Gonzalez', '06/01/1992', '***-**-9797', 'NA'],
#  ['87', 'John', 'Paul', '11/20/1973', '***-**-7180', 'NA'],
#  ['286', 'Stephanie', 'Smith', '04/26/1978', '***-**-1286', 'NA'],
#  ['221', 'Lisa', 'Wilson', '11/09/1993', '***-**-6950', 'NA'],
#  ['524', 'Cody', 'Duran', '01/15/1973', '***-**-6706', 'NA'],
#  ['453', 'Ann', 'Johnson', '06/01/1981', '***-**-9046', 'NA'],
#  ['468', 'Paula', 'Hernandez', '10/12/1975', '***-**-2951', 'NA'],
#  ['444', 'Patrick', 'Barber', '07/21/1991', '***-**-9891', 'NA'],
#  ['350', 'Dennis', 'Alvarado', '11/27/1973', '***-**-4378', 'NA'],
#  ['462', 'David', 'Peterson', '06/27/1973', '***-**-7312', 'NA'],
#  ['66', 'Tina', 'Williams', '11/04/1987', '***-**-7775', 'NA'],
#  ['495', 'Bridget', 'Koch', '02/23/1973', '***-**-9714', 'NA'],
#  ['586', 'Adrian', 'Hernandez', '09/08/1993', '***-**-5101', 'NA'],
#  ['457', 'Andrea', 'Potter', '12/26/1983', '***-**-6384', 'NA'],
#  ['392', 'David', 'Williams', '07/07/1990', '***-**-6350', 'NA'],
#  ['202', 'Katherine', 'Wright', '05/10/1987', '***-**-3109', 'NA'],
#  ['467', 'Kevin', 'Taylor', '04/19/1979', '***-**-2293', 'NA'],
#  ['627', 'Latoya', 'Mitchell', '03/15/1991', '***-**-3607', 'NA'],
#  ['367', 'Tricia', 'Smith', '01/24/1992', '***-**-7866', 'NA'],
#  ['244', 'David', 'Miles', '11/26/1993', '***-**-2657', 'NA'],
#  ['620', 'Gina', 'Hoffman', '03/20/1990', '***-**-4213', 'NA'],
#  ['642', 'Tamara', 'Whitney', '09/21/1975', '***-**-9208', 'NA'],
#  ['427', 'John', 'Garcia', '04/14/1987', '***-**-3993', 'NA'],
#  ['539', 'Craig', 'Nunez', '06/13/1972', '***-**-6566', 'NA'],
#  ['98', 'Desiree', 'Ross', '07/07/1981', '***-**-2608', 'NA'],
#  ['324', 'Samantha', 'Ramirez', '08/11/1981', '***-**-7086', 'NA'],
#  ['589', 'David', 'Patton', '11/19/1978', '***-**-9705', 'NA'],
#  ['339', 'Caroline', 'Lopez', '08/09/1981', '***-**-1325', 'NA'],
#  ['645', 'Karen', 'Malone', '09/03/1985', '***-**-5442', 'NA'],
#  ['355', 'Daniel', 'Wright', '12/31/1989', '***-**-3803', 'NA'],
#  ['541', 'Brent', 'Miller', '01/14/1978', '***-**-9692', 'NA'],
#  ['360', 'Mitchell', 'Meyer', '08/31/1991', '***-**-7666', 'NA'],
#  ['39', 'Annette', 'Flores', '04/19/1977', '***-**-3196', 'NA'],
#  ['305', 'Wendy', 'Hendrix', '08/19/1983', '***-**-6634', 'NA'],
#  ['474', 'Alexis', 'Cross', '08/11/1983', '***-**-3694', 'NA'],
#  ['571', 'Jeffrey', 'Jones', '06/27/1981', '***-**-1822', 'NA'],
#  ['372', 'Jessica', 'Walsh', '06/01/1976', '***-**-2907', 'NA'],
#  ['559', 'Sherry', 'Henderson', '02/15/1991', '***-**-3768', 'NA'],
#  ['521', 'Jennifer', 'Johnson', '02/17/1978', '***-**-3102', 'NA'],
#  ['583', 'Scott', 'Ellison', '03/31/1977', '***-**-8653', 'NA'],
#  ['329', 'Denise', 'Baldwin', '04/06/1992', '***-**-7350', 'AL'],
#  ['201', 'Rebecca', 'James', '12/04/1980', '***-**-1514', 'NA'],
#  ['276', 'Sean', 'Gonzales', '08/11/1981', '***-**-8838', 'NA'],
#  ['592', 'Mary', 'Chavez', '04/27/1990', '***-**-2834', 'NA'],
#  ['124', 'Ralph', 'Martinez', '02/26/1980', '***-**-4024', 'NA'],
#  ['133', 'Thomas', 'Stone', '03/29/1973', '***-**-8227', 'NA'],
#  ['314', 'Christopher', 'Anderson', '07/01/1974', '***-**-1835', 'NA'],
#  ['562', 'Allison', 'Garcia', '02/08/1983', '***-**-0105', 'NA'],
#  ['125', 'Charles', 'Hall', '09/15/1982', '***-**-7617', 'NA'],
#  ['625', 'Lawrence', 'Roach', '04/03/1991', '***-**-2080', 'NA'],
#  ['312', 'Christopher', 'Dougherty', '03/29/1978', '***-**-0986', 'AL'],
#  ['90', 'William', 'Small', '08/05/1990', '***-**-0642', 'NA'],
#  ['236', 'Samuel', 'May', '03/30/1988', '***-**-0970', 'NA'],
#  ['601', 'Brian', 'Lopez', '02/13/1990', '***-**-7558', 'NA'],
#  ['326', 'Amanda', 'Clark', '07/23/1991', '***-**-5043', 'NA'],
#  ['264', 'Cody', 'Taylor', '11/13/1978', '***-**-3700', 'NA'],
#  ['248', 'Sherry', 'Love', '03/24/1975', '***-**-8685', 'NA'],
#  ['485', 'Christine', 'Stone', '11/07/1978', '***-**-6503', 'NA'],
#  ['54', 'Kristy', 'Diaz', '03/26/1988', '***-**-1032', 'NA'],
#  ['2', 'Amy', 'Long', '07/19/1982', '***-**-7292', 'NA'],
#  ['298', 'Haley', 'Myers', '03/20/1985', '***-**-0757', 'NA'],
#  ['99', 'Michael', 'Holden', '07/23/1975', '***-**-7951', 'NA'],
#  ['186', 'Kelly', 'Ferrell', '01/21/1982', '***-**-2299', 'NA'],
#  ['593', 'Rachel', 'Valdez', '05/21/1985', '***-**-0852', 'NA'],
#  ['557', 'Kristine', 'Roberson', '03/18/1981', '***-**-0956', 'NA'],
#  ['375', 'Vincent', 'Watson', '12/15/1974', '***-**-8997', 'NA'],
#  ['460', 'Elizabeth', 'Bailey', '07/15/1979', '***-**-7230', 'NA'],
#  ['496', 'Mark', 'Mcmillan', '07/08/1976', '***-**-2503', 'NA'],
#  ['487', 'Sheri', 'Long', '06/06/1978', '***-**-5166', 'NA'],
#  ['469', 'Daniel', 'Mccall', '07/12/1987', '***-**-5314', 'NA'],
#  ['340', 'Dawn', 'Malone', '04/19/1979', '***-**-2070', 'NA'],
#  ['363', 'Evan', 'Romero', '08/25/1994', '***-**-3334', 'NA'],
#  ['108', 'Paul', 'Adams', '04/19/1992', '***-**-5765', 'NA'],
#  ['357', 'Tracy', 'Holt', '10/20/1988', '***-**-1413', 'NA'],
#  ['293', 'Charles', 'Wheeler', '02/11/1972', '***-**-5781', 'NA'],
#  ['604', 'Ashley', 'Harris', '08/09/1993', '***-**-7070', 'NA'],
#  ['7', 'Roberto', 'Schmidt', '02/07/1994', '***-**-1763', 'AL'],
#  ['94', 'Margaret', 'Barton', '10/10/1975', '***-**-0973', 'NA'],
#  ['227', 'Michelle', 'Diaz', '09/25/1993', '***-**-4889', 'NA'],
#  ['486', 'Mike', 'Duncan', '12/15/1988', '***-**-8115', 'NA'],
#  ['613', 'Alexandra', 'Thomas', '01/12/1994', '***-**-6760', 'NA'],
#  ['603', 'Mark', 'Murillo', '09/22/1976', '***-**-9915', 'NA'],
#  ['332', 'Carol', 'Dyer', '03/12/1989', '***-**-5545', 'NA'],
#  ['587', 'Daniel', 'Williams', '11/17/1989', '***-**-9146', 'NA'],
#  ['602', 'Sandra', 'Suarez', '09/20/1980', '***-**-9548', 'NA'],
#  ['398', 'Sarah', 'Hamilton', '07/20/1976', '***-**-3104', 'NA'],
#  ['148', 'Sydney', 'Floyd', '03/31/1981', '***-**-0722', 'NA'],
#  ['223', 'Jonathan', 'Hall', '07/01/1978', '***-**-6672', 'NA'],
#  ['574', 'Jennifer', 'Kim', '10/03/1976', '***-**-9504', 'NA'],
#  ['588', 'Kenneth', 'Sanchez', '10/30/1980', '***-**-8921', 'NA'],
#  ['157', 'Joseph', 'Carroll', '05/09/1975', '***-**-5984', 'NA'],
#  ['175', 'Jennifer', 'Arnold', '10/18/1976', '***-**-4368', 'AL'],
#  ['473', 'David', 'Le', '08/31/1976', '***-**-5444', 'NA'],
#  ['29', 'Jeffrey', 'Clark', '06/28/1978', '***-**-0316', 'NA'],
#  ['334', 'Jeffery', 'Reed', '07/19/1985', '***-**-6338', 'NA'],
#  ['465', 'Laura', 'Kim', '07/26/1974', '***-**-3606', 'NA'],
#  ['92', 'Derek', 'Obrien', '06/29/1990', '***-**-6123', 'NA'],
#  ['470', 'Brooke', 'Bishop', '12/18/1980', '***-**-4107', 'NA'],
#  ['128', 'Peter', 'Miles', '10/26/1976', '***-**-3367', 'NA'],
#  ['77', 'Alex', 'Owen', '10/07/1987', '***-**-9252', 'AL'],
#  ['530', 'Michael', 'Fowler', '08/28/1990', '***-**-3995', 'NA'],
#  ['270', 'Katherine', 'Rose', '01/19/1976', '***-**-0446', 'NA'],
#  ['251', 'Daniel', 'Waller', '04/23/1974', '***-**-0011', 'NA'],
#  ['277', 'Ronald', 'Johnson', '09/19/1973', '***-**-8871', 'NA'],
#  ['346', 'Austin', 'Gutierrez', '06/25/1979', '***-**-0203', 'NA'],
#  ['238', 'Brandon', 'Chang', '05/14/1984', '***-**-6687', 'AL'],
#  ['143', 'Alexander', 'Murphy', '05/05/1984', '***-**-0664', 'NA'],
#  ['461', 'Stephanie', 'Mendoza', '03/22/1977', '***-**-8308', 'NA'],
#  ['5', 'Gregory', 'Moore', '02/10/1982', '***-**-6226', 'NA'],
#  ['117', 'Jonathan', 'Mendoza', '12/30/1989', '***-**-0262', 'NA'],
#  ['396', 'Michelle', 'Phillips', '09/17/1988', '***-**-2345', 'NA'],
#  ['517', 'Justin', 'Morgan', '03/17/1976', '***-**-5133', 'NA'],
#  ['228', 'Michael', 'Hubbard', '09/09/1978', '***-**-8972', 'NA'],
#  ['576', 'Travis', 'Little', '05/14/1992', '***-**-6995', 'NA'],
#  ['482', 'Susan', 'Kennedy', '12/19/1988', '***-**-4558', 'NA'],
#  ['611', 'Emily', 'Mcgrath', '11/10/1973', '***-**-7640', 'NA'],
#  ['288', 'Sandra', 'Griffin', '11/13/1988', '***-**-6533', 'NA'],
#  ['322', 'Jessica', 'Sullivan', '01/07/1990', '***-**-2665', 'NA'],
#  ['93', 'Timothy', 'Mendoza', '06/09/1980', '***-**-2367', 'NA'],
#  ['631', 'Amanda', 'Pearson', '08/15/1979', '***-**-9832', 'NA'],
#  ['95', 'Jeffery', 'Burnett', '07/28/1984', '***-**-4493', 'NA'],
#  ['225', 'Brian', 'Williams', '01/12/1986', '***-**-5701', 'NA'],
#  ['386', 'Randy', 'Dorsey', '05/09/1974', '***-**-0360', 'NA'],
#  ['272', 'Duane', 'Williams', '10/14/1973', '***-**-8818', 'NA'],
#  ['614', 'Colleen', 'Beasley', '08/12/1977', '***-**-3286', 'NA'],
#  ['262', 'Brian', 'Jackson', '12/21/1985', '***-**-9597', 'NA'],
#  ['110', 'Cynthia', 'Price', '10/15/1991', '***-**-6184', 'NA'],
#  ['501', 'Donald', 'Carter', '07/16/1983', '***-**-5922', 'NA'],
#  ['65', 'Lisa', 'Schmitt', '04/23/1976', '***-**-5980', 'NA'],
#  ['458', 'Dustin', 'Nichols', '06/07/1977', '***-**-9015', 'NA'],
#  ['224', 'Jay', 'Brown', '04/24/1980', '***-**-8736', 'NA'],
#  ['160', 'Beth', 'Lynch', '02/13/1984', '***-**-0814', 'NA'],
#  ['259', 'Mary', 'Mitchell', '01/20/1982', '***-**-3602', 'NA'],
#  ['547', 'Joshua', 'Rush', '08/05/1986', '***-**-2710', 'NA'],
#  ['358', 'Jillian', 'David', '04/11/1973', '***-**-4462', 'NA'],
#  ['652', 'Anthony', 'Delgado', '09/19/1994', '***-**-7837', 'NA'],
#  ['49', 'Meghan', 'Wilson', '05/18/1988', '***-**-4722', 'NA'],
#  ['437', 'Andrea', 'Montgomery', '12/03/1991', '***-**-6315', 'NA'],
#  ['536', 'Megan', 'Gray', '10/12/1972', '***-**-4006', 'NA'],
#  ['636', 'Sarah', 'Brooks', '06/27/1991', '***-**-6948', 'NA'],
#  ['330', 'Kaylee', 'Clark', '05/29/1992', '***-**-0753', 'NA'],
#  ['538', 'Joseph', 'Martin', '04/13/1992', '***-**-5396', 'NA'],
#  ['168', 'Donna', 'Rose', '04/20/1989', '***-**-1960', 'NA'],
#  ['480', 'Brandi', 'Sawyer', '07/13/1979', '***-**-9334', 'NA'],
#  ['543', 'James', 'Torres', '01/19/1986', '***-**-5026', 'NA'],
#  ['506', 'Jonathan', 'Malone', '04/14/1984', '***-**-9942', 'NA'],
#  ['80', 'Christine', 'Williams', '08/15/1974', '***-**-1974', 'NA'],
#  ['342', 'Christopher', 'Young', '12/02/1988', '***-**-1343', 'NA'],
#  ['364', 'David', 'Turner', '02/13/1973', '***-**-7108', 'NA'],
#  ['64', 'Gregory', 'Estes', '10/04/1989', '***-**-9235', 'NA'],
#  ['156', 'Shannon', 'Vaughn', '12/27/1992', '***-**-2444', 'NA'],
#  ['285', 'James', 'Mclaughlin', '01/21/1981', '***-**-1088', 'NA'],
#  ['79', 'Michael', 'Brown', '01/13/1986', '***-**-9682', 'NA'],
#  ['170', 'Jennifer', 'Crawford', '07/21/1986', '***-**-5861', 'NA'],
#  ['561', 'Michelle', 'Carr', '06/22/1978', '***-**-2759', 'NA'],
#  ['617', 'Andrew', 'Love', '05/27/1991', '***-**-9696', 'NA'],
#  ['515', 'Anna', 'Bennett', '06/20/1977', '***-**-6909', 'NA'],
#  ['644', 'William', 'Watts', '10/12/1989', '***-**-6883', 'NA'],
#  ['450', 'Cynthia', 'Williams', '12/23/1978', '***-**-5994', 'NA'],
#  ['216', 'Bruce', 'Miles', '01/21/1982', '***-**-0969', 'NA'],
#  ['88', 'Amanda', 'Wilson', '05/23/1972', '***-**-0767', 'NA'],
#  ['130', 'Joshua', 'Riley', '11/08/1983', '***-**-4874', 'NA'],
#  ['408', 'Carla', 'Torres', '02/23/1987', '***-**-7599', 'NA'],
#  ['105', 'Mark', 'Green', '06/14/1977', '***-**-6893', 'NA'],
#  ['580', 'Stephanie', 'Goodwin', '02/25/1986', '***-**-5702', 'NA'],
#  ['388', 'Cameron', 'Allen', '01/02/1986', '***-**-8341', 'NA'],
#  ['316', 'Harold', 'Li', '05/11/1983', '***-**-2966', 'NA'],
#  ['196', 'Sara', 'Curry', '06/05/1984', '***-**-1678', 'NA'],
#  ['366', 'Caroline', 'Wyatt', '11/12/1979', '***-**-7063', 'NA'],
#  ['331', 'Nicole', 'Perez', '09/28/1982', '***-**-1455', 'NA'],
#  ['63', 'Jacqueline', 'Garcia', '01/31/1991', '***-**-8953', 'NA'],
#  ['651', 'Alexander', 'Wright', '04/18/1979', '***-**-7263', 'NA'],
#  ['497', 'Heather', 'Farrell', '01/11/1978', '***-**-0338', 'NA'],
#  ['14', 'Joseph', 'Fernandez', '06/01/1978', '***-**-4971', 'NA'],
#  ['52', 'Timothy', 'Chandler', '03/26/1978', '***-**-3897', 'NA'],
#  ['456', 'Gregory', 'Jackson', '06/06/1973', '***-**-0058', 'NA'],
#  ['412', 'Thomas', 'Patterson', '05/06/1977', '***-**-4561', 'NA'],
#  ['283', 'Timothy', 'Suarez', '01/12/1977', '***-**-3073', 'NA'],
#  ['174', 'Jennifer', 'Jensen', '03/09/1991', '***-**-4293', 'NA'],
#  ['509', 'Andrew', 'Hogan', '06/08/1990', '***-**-5943', 'NA'],
#  ['254', 'Dale', 'Hartman', '10/01/1993', '***-**-9502', 'NA'],
#  ['531', 'Jennifer', 'Williams', '02/27/1977', '***-**-9054', 'NA'],
#  ['104', 'Antonio', 'Perez', '02/09/1980', '***-**-4115', 'NA'],
#  ['549', 'Joshua', 'Hicks', '01/07/1985', '***-**-4786', 'NA'],
#  ['183', 'Edward', 'Thompson', '08/31/1994', '***-**-8605', 'NA'],
#  ['612', 'Lee', 'Zamora', '03/17/1979', '***-**-3321', 'NA'],
#  ['492', 'Wyatt', 'Rivers', '02/07/1984', '***-**-5135', 'NA'],
#  ['27', 'Michelle', 'Reeves', '11/23/1972', '***-**-1066', 'NA'],
#  ['287', 'Joanna', 'Hopkins', '04/17/1973', '***-**-2714', 'NA'],
#  ['584', 'Joseph', 'Mitchell', '05/18/1980', '***-**-7441', 'NA'],
#  ['624', 'Ariel', 'Ray', '09/11/1972', '***-**-2732', 'NA'],
#  ['53', 'Shawn', 'Murray', '10/30/1990', '***-**-5217', 'NA'],
#  ['206', 'Jose', 'Spears', '03/01/1976', '***-**-2675', 'NA'],
#  ['211', 'Caroline', 'Mayer', '05/03/1973', '***-**-2487', 'NA'],
#  ['646', 'David', 'Weaver', '08/11/1976', '***-**-2750', 'NA'],
#  ['336', 'Kelly', 'Sullivan', '04/12/1988', '***-**-7284', 'NA'],
#  ['555', 'Kyle', 'Ramirez', '05/30/1984', '***-**-2839', 'NA'],
#  ['560', 'Carrie', 'Davis', '06/20/1984', '***-**-6558', 'NA'],
#  ['203', 'Catherine', 'Martinez', '04/28/1990', '***-**-6917', 'NA'],
#  ['217', 'Amanda', 'Lewis', '12/05/1988', '***-**-0504', 'NA'],
#  ['371', 'Katherine', 'Bailey', '03/04/1994', '***-**-3545', 'NA'],
#  ['605', 'Rodney', 'Smith', '05/08/1975', '***-**-3105', 'NA'],
#  ['337', 'Savannah', 'Saunders', '05/12/1984', '***-**-2473', 'NA'],
#  ['381', 'Claudia', 'Oneal', '04/01/1987', '***-**-9008', 'NA'],
#  ['508', 'Roy', 'Johnson', '03/30/1984', '***-**-6344', 'NA'],
#  ['58', 'Michelle', 'Smith', '07/08/1982', '***-**-6834', 'NA'],
#  ['401', 'Amanda', 'Haney', '04/11/1983', '***-**-9019', 'NA'],
#  ['163', 'Theresa', 'Fletcher', '10/22/1992', '***-**-0535', 'NA'],
#  ['548', 'Debra', 'Green', '07/20/1988', '***-**-5376', 'NA'],
#  ['161', 'John', 'Cox', '12/11/1985', '***-**-7739', 'NA'],
#  ['464', 'Beth', 'Harris', '12/22/1982', '***-**-5871', 'NA'],
#  ['476', 'Erica', 'Mcconnell', '07/01/1981', '***-**-0878', 'NA'],
#  ['208', 'Kimberly', 'Johnson', '01/22/1992', '***-**-4304', 'NA'],
#  ['378', 'Kyle', 'Aguirre', '10/24/1973', '***-**-4469', 'NA'],
#  ['654', 'Nicole', 'English', '04/30/1977', '***-**-9164', 'NA'],
#  ['585', 'Bonnie', 'Turner', '04/01/1973', '***-**-0208', 'NA'],
#  ['621', 'Maurice', 'Gillespie', '09/07/1984', '***-**-8509', 'NA'],
#  ['300', 'Corey', 'Adams', '10/08/1988', '***-**-2578', 'NA'],
#  ['640', 'Brett', 'Nelson', '06/20/1986', '***-**-3049', 'NA'],
#  ['297', 'Melody', 'Nelson', '01/23/1979', '***-**-1931', 'NA'],
#  ['209', 'James', 'Young', '04/12/1980', '***-**-8557', 'NA'],
#  ['320', 'Robert', 'Smith', '04/14/1994', '***-**-0748', 'NA'],
#  ['242', 'Caroline', 'Larson', '05/05/1990', '***-**-7178', 'NA'],
#  ['258', 'Megan', 'Robinson', '03/24/1973', '***-**-1601', 'NA'],
#  ['570', 'Shawn', 'Edwards', '01/19/1978', '***-**-4865', 'NA'],
#  ['417', 'David', 'Evans', '09/15/1977', '***-**-6773', 'NA'],
#  ['281', 'Julie', 'Price', '01/20/1993', '***-**-3599', 'NA'],
#  ['436', 'Briana', 'Webster', '02/08/1978', '***-**-3704', 'NA'],
#  ['441', 'Robin', 'Oconnor', '02/27/1978', '***-**-0782', 'NA'],
#  ['425', 'Albert', 'Davidson', '01/20/1975', '***-**-9182', 'NA'],
#  ['553', 'Mark', 'Chen', '04/02/1989', '***-**-3553', 'NA'],
#  ['266', 'Elizabeth', 'Lynn', '02/25/1992', '***-**-8647', 'NA'],
#  ['40', 'Tracy', 'Gonzalez', '11/01/1983', '***-**-4059', 'NA'],
#  ['609', 'Patricia', 'Fletcher', '06/30/1979', '***-**-2311', 'NA'],
#  ['471', 'Tammy', 'Salinas', '12/29/1980', '***-**-3850', 'NA'],
#  ['307', 'Roger', 'Wright', '03/04/1974', '***-**-3080', 'NA'],
#  ['353', 'Kelly', 'Castillo', '04/13/1992', '***-**-7622', 'NA'],
#  ['393', 'Charles', 'Kelley', '04/14/1993', '***-**-1133', 'NA'],
#  ['607', 'David', 'Johnson', '06/23/1985', '***-**-9729', 'NA'],
#  ['483', 'David', 'Cervantes', '01/08/1983', '***-**-0082', 'NA'],
#  ['370', 'Valerie', 'Lopez', '04/10/1983', '***-**-0441', 'AL'],
#  ['273', 'Sarah', 'Hayes', '11/20/1984', '***-**-8195', 'NA'],
#  ['141', 'Christina', 'Arnold', '10/20/1979', '***-**-2313', 'NA'],
#  ['338', 'Cynthia', 'Bennett', '11/26/1973', '***-**-7899', 'NA'],
#  ['15', 'Michelle', 'Huang', '04/09/1983', '***-**-8363', 'NA'],
#  ['120', 'Amanda', 'Dodson', '03/04/1973', '***-**-6056', 'NA'],
#  ['75', 'Jeff', 'Hawkins', '08/10/1992', '***-**-5606', 'NA'],
#  ['115', 'Patrick', 'Taylor', '07/29/1991', '***-**-5595', 'NA'],
#  ['629', 'Elizabeth', 'Howard', '11/05/1984', '***-**-2641', 'NA'],
#  ['299', 'Noah', 'White', '04/30/1977', '***-**-0897', 'NA'],
#  ['498', 'Caroline', 'Jackson', '12/29/1983', '***-**-4102', 'NA'],
#  ['445', 'Andrea', 'Wright', '06/15/1978', '***-**-8386', 'NA'],
#  ['582', 'Sara', 'Smith', '01/02/1983', '***-**-9188', 'NA'],
#  ['245', 'Jennifer', 'Rodriguez', '04/23/1974', '***-**-2538', 'NA'],
#  ['129', 'Deanna', 'Terrell', '02/05/1990', '***-**-5743', 'NA'],
#  ['544', 'Kristina', 'Summers', '02/17/1989', '***-**-3058', 'NA'],
#  ['377', 'Laura', 'Mercado', '04/05/1974', '***-**-9514', 'NA'],
#  ['155', 'Matthew', 'Kane', '11/17/1990', '***-**-9385', 'NA'],
#  ['440', 'Tamara', 'White', '05/20/1980', '***-**-6614', 'NA'],
#  ['550', 'Samantha', 'Thompson', '06/04/1976', '***-**-9230', 'NA'],
#  ['47', 'John', 'Mcmillan', '03/02/1983', '***-**-7301', 'NA'],
#  ['89', 'Andrea', 'Webb', '12/11/1985', '***-**-7815', 'NA'],
#  ['145', 'Lori', 'Odonnell', '10/22/1989', '***-**-2415', 'NA'],
#  ['554', 'Ronald', 'Huerta', '12/13/1973', '***-**-6058', 'NA'],
#  ['523', 'Chelsea', 'Foster', '03/26/1974', '***-**-4094', 'NA'],
#  ['499', 'Daniel', 'Lopez', '09/07/1989', '***-**-2639', 'NA'],
#  ['37', 'Jonathan', 'Jones', '01/13/1977', '***-**-7798', 'NA'],
#  ['384', 'Jessica', 'Gaines', '04/23/1981', '***-**-9332', 'NA'],
#  ['514', 'Timothy', 'Morris', '06/16/1981', '***-**-2962', 'NA'],
#  ['260', 'Donna', 'Campbell', '07/14/1993', '***-**-2369', 'NA'],
#  ['239', 'Tonya', 'Martinez', '09/04/1972', '***-**-7702', 'NA'],
#  ['420', 'Pamela', 'Moore', '02/20/1980', '***-**-9532', 'NA'],
#  ['380', 'Michelle', 'Ali', '05/05/1993', '***-**-3823', 'NA'],
#  ['387', 'Alexander', 'Gibson', '10/27/1983', '***-**-1036', 'NA'],
#  ['207', 'Jay', 'Smith', '03/06/1985', '***-**-6315', 'NA'],
#  ['318', 'Teresa', 'Watkins', '07/27/1972', '***-**-5707', 'NA'],
#  ['16', 'Bradley', 'Guzman', '05/08/1980', '***-**-2817', 'NA'],
#  ['61', 'Rhonda', 'Young', '06/03/1979', '***-**-2336', 'NA'],
#  ['280', 'Brandon', 'Davis', '07/22/1977', '***-**-1621', 'NA'],
#  ['13', 'Brandon', 'Farmer', '08/10/1980', '***-**-2601', 'NA'],
#  ['563', 'Barbara', 'Murphy', '10/30/1989', '***-**-9225', 'NA'],
#  ['569', 'James', 'King', '04/21/1978', '***-**-1432', 'NA'],
#  ['575', 'Drew', 'Kelly', '03/25/1993', '***-**-3264', 'NA'],
#  ['319', 'Virginia', 'Wise', '02/18/1982', '***-**-8887', 'NA'],
#  ['122', 'Mary', 'Hernandez', '01/29/1990', '***-**-5268', 'NA'],
#  ['520', 'Ryan', 'Russell', '01/06/1975', '***-**-3828', 'NA'],
#  ['489', 'Amanda', 'Smith', '08/05/1989', '***-**-3579', 'NA'],
#  ['136', 'Morgan', 'Dunn', '07/13/1980', '***-**-1601', 'NA'],
#  ['142', 'Kimberly', 'Shaw', '06/11/1973', '***-**-7577', 'NA'],
#  ['250', 'Kathleen', 'Klein', '01/15/1990', '***-**-3388', 'NA'],
#  ['383', 'Diana', 'Meyers', '09/13/1972', '***-**-4296', 'NA'],
#  ['650', 'Logan', 'Smith', '03/26/1990', '***-**-0194', 'NA'],
#  ['231', 'Tracy', 'Martin', '05/03/1975', '***-**-0726', 'NA'],
#  ['431', 'Edwin', 'Martin', '02/13/1988', '***-**-9168', 'NA'],
#  ['306', 'Kelly', 'Moran', '07/14/1976', '***-**-0670', 'NA'],
#  ['151', 'Robert', 'Smith', '01/12/1987', '***-**-2300', 'NA'],
#  ['519', 'Jane', 'Martinez', '01/30/1991', '***-**-3977', 'NA'],
#  ['172', 'Denise', 'Castillo', '10/10/1983', '***-**-0042', 'NA'],
#  ['121', 'Jonathon', 'Brock', '04/30/1980', '***-**-9917', 'NA'],
#  ['140', 'Amanda', 'Franco', '09/24/1994', '***-**-5413', 'NA'],
#  ['48', 'Heather', 'Robinson', '11/20/1985', '***-**-1929', 'NA'],
#  ['282', 'Kathryn', 'Stout', '08/24/1987', '***-**-9637', 'NA'],
#  ['42', 'Cory', 'Hopkins', '03/13/1977', '***-**-9491', 'NA'],
#  ['247', 'Ryan', 'Snyder', '07/14/1982', '***-**-9330', 'NA'],
#  ['59', 'Sara', 'Walker', '08/16/1985', '***-**-5423', 'NA'],
#  ['137', 'Daniel', 'Garcia', '04/21/1979', '***-**-3001', 'NA'],
#  ['257', 'Paul', 'Evans', '06/25/1977', '***-**-4302', 'NA'],
#  ['343', 'Elizabeth', 'Olson', '01/22/1976', '***-**-7163', 'NA'],
#  ['195', 'Ann', 'Romero', '10/27/1989', '***-**-4046', 'NA'],
#  ['268', 'Thomas', 'Jensen', '02/23/1991', '***-**-3430', 'NA'],
#  ['558', 'Brian', 'Davila', '07/05/1982', '***-**-3711', 'NA'],
#  ['70', 'Donna', 'Howard', '03/31/1990', '***-**-7432', 'NA'],
#  ['28', 'Kimberly', 'Massey', '01/01/1981', '***-**-4649', 'NA'],
#  ['132', 'Jeremy', 'Cross', '11/22/1987', '***-**-4632', 'NA'],
#  ['335', 'Dennis', 'Thomas', '06/11/1989', '***-**-5032', 'NA'],
#  ['349', 'Kenneth', 'Martin', '08/24/1989', '***-**-4681', 'NA'],
#  ['510', 'Tyler', 'Brewer', '06/28/1972', '***-**-9006', 'NA'],
#  ['36', 'Scott', 'Brooks', '02/24/1972', '***-**-4958', 'NA'],
#  ['430', 'Derrick', 'Fritz', '12/05/1982', '***-**-0071', 'NA'],
#  ['376', 'Christine', 'Munoz', '11/17/1974', '***-**-0149', 'NA'],
#  ['226', 'Julie', 'Robbins', '11/23/1976', '***-**-4571', 'NA'],
#  ['240', 'Rachel', 'Cook', '03/03/1982', '***-**-9042', 'NA'],
#  ['291', 'Kyle', 'Hoffman', '12/25/1984', '***-**-7692', 'NA'],
#  ['619', 'Nancy', 'Nguyen', '07/05/1976', '***-**-3939', 'NA'],
#  ['424', 'John', 'Wells', '05/25/1993', '***-**-3026', 'NA'],
#  ['212', 'Robert', 'Ellison', '07/16/1979', '***-**-9579', 'NA'],
#  ['263', 'Keith', 'Robinson', '04/15/1978', '***-**-3579', 'NA'],
#  ['443', 'Dennis', 'Osborn', '11/15/1973', '***-**-3531', 'NA'],
#  ['26', 'Ronald', 'Hays', '12/21/1993', '***-**-6430', 'NA'],
#  ['491', 'Leslie', 'Brown', '06/15/1973', '***-**-1806', 'NA'],
#  ['114', 'Maria', 'Chapman', '12/20/1973', '***-**-7300', 'NA'],
#  ['434', 'Melissa', 'Torres', '03/22/1981', '***-**-6921', 'NA'],
#  ['615', 'Joshua', 'Weaver', '11/20/1982', '***-**-7030', 'NA'],
#  ['525', 'Crystal', 'Martin', '08/29/1993', '***-**-0679', 'NA'],
#  ['44', 'Sheri', 'Ball', '08/04/1991', '***-**-7548', 'NA'],
#  ['475', 'Steven', 'Ritter', '02/11/1986', '***-**-8004', 'NA'],
#  ['529', 'Linda', 'Krause', '12/22/1978', '***-**-4382', 'NA'],
#  ['83', 'John', 'Myers', '07/25/1989', '***-**-1869', 'NA'],
#  ['275', 'Mark', 'White', '09/09/1992', '***-**-7830', 'NA'],
#  ['190', 'Diana', 'Smith', '12/02/1973', '***-**-3506', 'NA'],
#  ['423', 'Karen', 'Lyons', '06/09/1990', '***-**-9081', 'NA'],
#  ['581', 'Laura', 'Glenn', '10/20/1992', '***-**-1468', 'NA'],
#  ['177', 'Diana', 'Spence', '09/20/1983', '***-**-4751', 'NA'],
#  ['573', 'Samantha', 'Farley', '07/10/1977', '***-**-2351', 'NA'],
#  ['46', 'Kayla', 'Mitchell', '10/13/1975', '***-**-9155', 'NA'],
#  ['17', 'Crystal', 'Myers', '12/31/1980', '***-**-6532', 'NA'],
#  ['101', 'Brooke', 'Jones', '04/09/1979', '***-**-2606', 'NA'],
#  ['261', 'John', 'Mueller', '03/22/1987', '***-**-7849', 'NA'],
#  ['435', 'Karla', 'Rosales', '07/10/1983', '***-**-1729', 'NA'],
#  ['448', 'Jennifer', 'Brown', '08/23/1977', '***-**-0700', 'NA'],
#  ['597', 'Blake', 'Jimenez', '09/10/1977', '***-**-3810', 'NA'],
#  ['628', 'Michael', 'Garcia', '11/05/1980', '***-**-4294', 'NA'],
#  ['610', 'Jermaine', 'Quinn', '12/24/1989', '***-**-1754', 'NA'],
#  ['113', 'Patricia', 'Cruz', '04/22/1976', '***-**-3822', 'NA'],
#  ['235', 'Cameron', 'Mcintosh', '02/01/1975', '***-**-8921', 'NA'],
#  ['21', 'Michelle', 'Brewer', '06/10/1988', '***-**-6836', 'NA'],
#  ['362', 'Hannah', 'Nolan', '09/15/1978', '***-**-1332', 'NA'],
#  ['368', 'Erica', 'Johnson', '05/27/1978', '***-**-9413', 'NA'],
#  ['323', 'Jeremy', 'Obrien', '01/13/1982', '***-**-7592', 'NA']]
